# %%
print("Multimodal Fusion Engine Initialized")
# Out:
# Multimodal Fusion Engine Initialized

# %%
mri_risk = 0.72
speech_risk = 0.28
cognitive_risk = 0.65
ehr_risk = 0.92
wearable_risk = 0.77
emotion_risk = 0.90

print("MRI Risk:", mri_risk)
print("Speech Risk:", speech_risk)
print("Cognitive Risk:", cognitive_risk)
print("EHR Risk:", ehr_risk)
print("Wearable Risk:", wearable_risk)
print("Emotion Risk:", emotion_risk)
# Out:
# MRI Risk: 0.72
# Speech Risk: 0.28
# Cognitive Risk: 0.65
# EHR Risk: 0.92
# Wearable Risk: 0.77
# Emotion Risk: 0.9

# %%
final_risk = (
    mri_risk +
    speech_risk +
    cognitive_risk +
    ehr_risk +
    wearable_risk +
    emotion_risk
) / 6

print("Final Alzheimer Risk Score:", round(final_risk, 2))
# Out:
# Final Alzheimer Risk Score: 0.71

# %%
if final_risk > 0.60:
    print("Prediction: High Alzheimer's Risk")
else:
    print("Prediction: Low Alzheimer's Risk")
# Out:
# Prediction: High Alzheimer's Risk

# %%
import matplotlib.pyplot as plt

modules = [
    "MRI",
    "Speech",
    "Cognitive",
    "EHR",
    "Wearable",
    "Emotion"
]

scores = [
    mri_risk,
    speech_risk,
    cognitive_risk,
    ehr_risk,
    wearable_risk,
    emotion_risk
]

plt.figure(figsize=(8,4))
plt.bar(modules, scores)

plt.title("Multimodal Alzheimer Risk Analysis")
plt.ylabel("Risk Score")

plt.show()

# %%
# Real module outputs

mri_risk = 0.72

speech_risk = 0.61   # Speech notebook accuracy 61%

cognitive_risk = 0.90   # Highest cognitive risk from MMSE

ehr_risk = 0.50   # Temporary

wearable_risk = 0.50   # Temporary

emotion_risk = 0.69   # Fearful emotion count proportion

# %%
final_risk = (
    mri_risk +
    speech_risk +
    cognitive_risk +
    ehr_risk +
    wearable_risk +
    emotion_risk
) / 6

print("Final Alzheimer Risk Score:", round(final_risk, 2))
# Out:
# Final Alzheimer Risk Score: 0.65

# %%
if final_risk < 0.4:
    prediction = "LOW RISK"

elif final_risk < 0.7:
    prediction = "MODERATE RISK"

else:
    prediction = "HIGH RISK"

print("Alzheimer Prediction:", prediction)
# Out:
# Alzheimer Prediction: MODERATE RISK

# %%
import matplotlib.pyplot as plt

modules = [
    "MRI",
    "Speech",
    "Cognitive",
    "EHR",
    "Wearable",
    "Emotion"
]

scores = [
    mri_risk,
    speech_risk,
    cognitive_risk,
    ehr_risk,
    wearable_risk,
    emotion_risk
]

plt.figure(figsize=(8,4))
plt.bar(modules, scores)
plt.title("Multimodal Alzheimer Risk Analysis")
plt.ylabel("Risk Score")
plt.show()

# %%
print("="*50)
print("ALZHEIMER EARLY PREDICTION REPORT")
print("="*50)

print("MRI Risk Score      :", mri_risk)
print("Speech Risk Score   :", speech_risk)
print("Cognitive Risk Score:", cognitive_risk)
print("EHR Risk Score      :", ehr_risk)
print("Wearable Risk Score :", wearable_risk)
print("Emotion Risk Score  :", emotion_risk)

print("\nFinal Risk Score:", round(final_risk,2))
print("Prediction:", prediction)

if prediction == "LOW RISK":
    print("\nRecommendation: Continue healthy lifestyle and regular monitoring.")

elif prediction == "MODERATE RISK":
    print("\nRecommendation: Periodic cognitive assessment is advised.")

else:
    print("\nRecommendation: Immediate neurological evaluation recommended.")

print("="*50)
# Out:
# ...
# ALZHEIMER EARLY PREDICTION REPORT
# ...
# MRI Risk Score      : 0.72
# Speech Risk Score   : 0.61
# Cognitive Risk Score: 0.9
# EHR Risk Score      : 0.5
# Wearable Risk Score : 0.5
# Emotion Risk Score  : 0.69
#
# Final Risk Score: 0.65
# Prediction: MODERATE RISK
#
# Recommendation: Periodic cognitive assessment is advised.
# ...
